# %%
import pandas as pd
import pandas as pnd
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm
from math import pi

# %%
datosBasilea = pd.read_csv('C:/Users/PC/Desktop/datosBasilea1.csv', sep = ',') #subimos csv (en sep ponemos como estan separadas las lineas)

# %%
datosBasilea.head()
# Out:
#        timestamp  Basilea Temperature [2 m elevation corrected]  \
# 0  20150101T0000                                      -3.289754
# 1  20150101T0100                                      -3.219755
# 2  20150101T0200                                      -3.339755
# 3  20150101T0300                                      -3.709755
# 4  20150101T0400                                      -3.809755
#
#    Basilea Precipitation Total  Basilea Wind Speed [10 m]  \
# 0                          0.0                   6.877790
# 1                          0.0                   7.280550
# 2                          0.0                   7.208994
# 3                          0.0                   6.130579
# 4                          0.0                   5.411986
#
#    Basilea Wind Direction [10 m]  Basilea Mean Sea Level Pressure [MSL]  \
# 0                      83.990990                                 1036.6
# 1                      81.469230                                 1036.6
# ...

# %%
datosBasilea
# Out:
#            timestamp  Basilea Temperature [2 m elevation corrected]  \
# 0      20150101T0000                                      -3.289754
# 1      20150101T0100                                      -3.219755
# 2      20150101T0200                                      -3.339755
# 3      20150101T0300                                      -3.709755
# 4      20150101T0400                                      -3.809755
# ...              ...                                            ...
# 70123  20221231T1900                                      13.750245
# 70124  20221231T2000                                      13.550245
# 70125  20221231T2100                                      13.410245
# 70126  20221231T2200                                      12.940246
# 70127  20221231T2300                                      12.350245
#
#        Basilea Precipitation Total  Basilea Wind Speed [10 m]  \
# 0                              0.0                   6.877790
# ...

# %%
datosBasilea.replace(-9999.0, np.nan, inplace=True) #remplazar los -9999.0 por Nan

# %%
datosBasilea_sin_valores = datosBasilea.dropna() #elimina filas con valores Nan

# %%
datosBasilea_sin_valores = datosBasilea.dropna(axis=1) #elimina columna con valores Nan

# %%
datosBasilea = datosBasilea.dropna() 
datosBasilea
# Out:
#            timestamp  Basilea Temperature [2 m elevation corrected]  \
# 0      20150101T0000                                      -3.289754
# 1      20150101T0100                                      -3.219755
# 2      20150101T0200                                      -3.339755
# 3      20150101T0300                                      -3.709755
# 4      20150101T0400                                      -3.809755
# ...              ...                                            ...
# 70123  20221231T1900                                      13.750245
# 70124  20221231T2000                                      13.550245
# 70125  20221231T2100                                      13.410245
# 70126  20221231T2200                                      12.940246
# 70127  20221231T2300                                      12.350245
#
#        Basilea Precipitation Total  Basilea Wind Speed [10 m]  \
# 0                              0.0                   6.877790
# ...

# %%
datosBasilea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70128 entries, 0 to 70127
# Data columns (total 7 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   timestamp                                      70128 non-null  object
#  1   Basilea Temperature [2 m elevation corrected]  70128 non-null  float64
#  2   Basilea Precipitation Total                    70128 non-null  float64
#  3   Basilea Wind Speed [10 m]                      70128 non-null  float64
#  4   Basilea Wind Direction [10 m]                  70128 non-null  float64
#  5   Basilea Mean Sea Level Pressure [MSL]          70128 non-null  float64
#  6   Basilea Geopotential Height [500 mb]           70128 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 3.7+ MB

# %%
datosBasilea.columns
# Out:
# Index(['timestamp', 'Basilea Temperature [2 m elevation corrected]',
#        'Basilea Precipitation Total', 'Basilea Wind Speed [10 m]',
#        'Basilea Wind Direction [10 m]',
#        'Basilea Mean Sea Level Pressure [MSL]',
#        'Basilea Geopotential Height [500 mb]'],
#       dtype='object')

# %%
datosBasilea = pnd.read_csv("C:/Users/PC/Desktop/datosBasilea1.csv", index_col=0, parse_dates=True)  # utilizamos index_col por que tiene datos(con fechas)

# %%
datosBasilea.index
# Out:
# DatetimeIndex(['2015-01-01 00:00:00', '2015-01-01 01:00:00',
#                '2015-01-01 02:00:00', '2015-01-01 03:00:00',
#                '2015-01-01 04:00:00', '2015-01-01 05:00:00',
#                '2015-01-01 06:00:00', '2015-01-01 07:00:00',
#                '2015-01-01 08:00:00', '2015-01-01 09:00:00',
#                ...
#                '2022-12-31 14:00:00', '2022-12-31 15:00:00',
#                '2022-12-31 16:00:00', '2022-12-31 17:00:00',
#                '2022-12-31 18:00:00', '2022-12-31 19:00:00',
#                '2022-12-31 20:00:00', '2022-12-31 21:00:00',
#                '2022-12-31 22:00:00', '2022-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=70128, freq=None)

# %%
datosBasilea['Año'] = datosBasilea.index.year       #utilizamos la funcion .index (para ver la fecha( en mes,año y dia separado))                         
datosBasilea['Mes'] = datosBasilea.index.month                               
datosBasilea['Dia'] = datosBasilea.index.day                        
datosBasilea.sample(45, random_state=0)  #para visualizar  45 datos
# Out:
#                      Basilea Temperature [2 m elevation corrected]  \
# timestamp
# 2019-11-17 09:00:00                                       2.250246
# 2019-06-02 07:00:00                                      15.770246
# 2017-08-23 23:00:00                                      23.620245
# 2017-12-03 05:00:00                                      -1.389755
# 2017-03-29 06:00:00                                       6.500245
# 2016-09-24 14:00:00                                      21.080246
# 2015-07-12 04:00:00                                      17.750246
# 2019-01-01 00:00:00                                       6.890245
# 2016-07-11 07:00:00                                      20.570246
# 2015-06-17 14:00:00                                      20.690245
# 2017-06-18 13:00:00                                      25.870245
# 2020-04-06 06:00:00                                       4.000246
# 2016-11-14 14:00:00                                       3.430245
# ...

# %%
datosBasilea.loc["2019-11-17"] #ver datos de un año
# Out:
#                      Basilea Temperature [2 m elevation corrected]  \
# timestamp
# 2019-11-17 00:00:00                                       0.190245
# 2019-11-17 01:00:00                                       0.390245
# 2019-11-17 02:00:00                                       0.450245
# 2019-11-17 03:00:00                                       0.350245
# 2019-11-17 04:00:00                                       0.960245
# 2019-11-17 05:00:00                                       1.140245
# 2019-11-17 06:00:00                                       1.190245
# 2019-11-17 07:00:00                                       1.510245
# 2019-11-17 08:00:00                                       1.920245
# 2019-11-17 09:00:00                                       2.250246
# 2019-11-17 10:00:00                                       2.840245
# 2019-11-17 11:00:00                                       3.450245
# 2019-11-17 12:00:00                                       3.630245
# ...

# %%
import matplotlib.pyplot as mplt

# %%
import seaborn as sbn
sbn.set(rc={'figure.figsize':(10, 5)})

# %%
datosBasilea['Basilea Geopotential Height [500 mb]'].plot(linewidth=0.1,xlabel='Años',ylabel= "Geopotencial(500 mb)",title='Evolución del geopotencial ')
# Out:
# <AxesSubplot:title={'center':'Evolución del geopotencial '}, xlabel='Años', ylabel='Geopotencial(500 mb)'>

# %%
datosBasilea['Basilea Mean Sea Level Pressure [MSL]'].plot(linewidth=0.1,xlabel='Años',ylabel= "Presión en superficie (hPa)",title='Evolución de la presion en superficie  ')
# Out:
# <AxesSubplot:title={'center':'Evolución de la presion en superficie  '}, xlabel='Años', ylabel='Presión en superficie (hPa)'>

# %%
datosBasilea['Basilea Precipitation Total'].plot(linewidth=0.1,xlabel='Años',ylabel= "Toal Precipitacion (pulgadas)",title="Evolución de la precipitacion")
# Out:
# <AxesSubplot:title={'center':'Evolución de la precipitacion'}, xlabel='Años', ylabel='Toal Precipitacion (pulgadas)'>

# %%
datosBasilea["Basilea Wind Speed [10 m]"].plot(linewidth=0.1,xlabel='Años',ylabel= "Velocidad viento (km/h)",title="Evolución del viento")
# Out:
# <AxesSubplot:title={'center':'Evolución del viento'}, xlabel='Años', ylabel='Velocidad viento (km/h)'>

# %%
eje = datosBasilea.loc['2016','Basilea Geopotential Height [500 mb]'].plot(xlabel='Meses',title="Evolución del geopotencial  en el año 2016")
eje.set_ylabel('mb')
# Out:
# Text(0, 0.5, 'mb')

# %%
eje = datosBasilea.loc['2016','Basilea Mean Sea Level Pressure [MSL]'].plot(xlabel='Meses',title="Evolución de la presion en el año 2016")
eje.set_ylabel("hPa")
# Out:
# Text(0, 0.5, 'hPa')
